# %%
import json
import time
import random
from datetime import datetime
from kafka import KafkaProducer

producer = KafkaProducer(
    bootstrap_servers='localhost:9092',
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

cities = ["New York", "San Francisco", "Chicago", "Boston", "Seattle"]

def generate_ride_event():
    return {
        "ride_id": random.randint(1000000, 9999999),
        "city": random.choice(cities),
        "timestamp": datetime.now().isoformat(),
        "distance_km": round(random.uniform(1.0, 15.0), 2),
        "fare_usd": round(random.uniform(5.0, 40.0), 2)
    }

print("Producing ride events...")

while True:
    event = generate_ride_event()
    producer.send("uber-rides", event)
    print("Sent:", event)
    time.sleep(1)
# Out:
# Producing ride events...
# Sent: {'ride_id': 9750137, 'city': 'New York', 'timestamp': '2025-12-03T16:41:50.347180', 'distance_km': 2.09, 'fare_usd': 19.11}
# Sent: {'ride_id': 1441707, 'city': 'Seattle', 'timestamp': '2025-12-03T16:41:51.470231', 'distance_km': 7.79, 'fare_usd': 6.65}
# Sent: {'ride_id': 4900833, 'city': 'Seattle', 'timestamp': '2025-12-03T16:41:52.480241', 'distance_km': 7.98, 'fare_usd': 13.82}
# Sent: {'ride_id': 2474937, 'city': 'New York', 'timestamp': '2025-12-03T16:41:53.490914', 'distance_km': 8.51, 'fare_usd': 22.27}
# Sent: {'ride_id': 6569708, 'city': 'Seattle', 'timestamp': '2025-12-03T16:41:54.500528', 'distance_km': 6.0, 'fare_usd': 6.21}
# Sent: {'ride_id': 8494919, 'city': 'Seattle', 'timestamp': '2025-12-03T16:41:55.509144', 'distance_km': 4.52, 'fare_usd': 15.23}
# Sent: {'ride_id': 9160987, 'city': 'San Francisco', 'timestamp': '2025-12-03T16:41:56.521380', 'distance_km': 1.61, 'fare_usd': 39.66}
# Sent: {'ride_id': 2734128, 'city': 'New York', 'timestamp': '2025-12-03T16:41:57.536242', 'distance_km': 11.74, 'fare_usd': 25.1}
# Sent: {'ride_id': 5822577, 'city': 'New York', 'timestamp': '2025-12-03T16:41:58.548939', 'distance_km': 8.66, 'fare_usd': 19.63}
# Sent: {'ride_id': 4781069, 'city': 'San Francisco', 'timestamp': '2025-12-03T16:41:59.559849', 'distance_km': 7.16, 'fare_usd': 25.2}
# Sent: {'ride_id': 3549338, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:00.562831', 'distance_km': 5.89, 'fare_usd': 10.93}
# Sent: {'ride_id': 3477875, 'city': 'Chicago', 'timestamp': '2025-12-03T16:42:01.576557', 'distance_km': 14.9, 'fare_usd': 14.62}
# Sent: {'ride_id': 5907610, 'city': 'San Francisco', 'timestamp': '2025-12-03T16:42:02.586301', 'distance_km': 13.17, 'fare_usd': 39.31}
# Sent: {'ride_id': 6547223, 'city': 'San Francisco', 'timestamp': '2025-12-03T16:42:03.599138', 'distance_km': 14.11, 'fare_usd': 34.7}
# Sent: {'ride_id': 7808046, 'city': 'Boston', 'timestamp': '2025-12-03T16:42:04.601742', 'distance_km': 1.35, 'fare_usd': 27.3}
# Sent: {'ride_id': 3357116, 'city': 'New York', 'timestamp': '2025-12-03T16:42:05.606210', 'distance_km': 14.53, 'fare_usd': 37.04}
# Sent: {'ride_id': 8404156, 'city': 'Chicago', 'timestamp': '2025-12-03T16:42:06.616214', 'distance_km': 2.9, 'fare_usd': 27.54}
# Sent: {'ride_id': 1545014, 'city': 'San Francisco', 'timestamp': '2025-12-03T16:42:07.626134', 'distance_km': 6.56, 'fare_usd': 11.14}
# Sent: {'ride_id': 4301903, 'city': 'San Francisco', 'timestamp': '2025-12-03T16:42:08.639344', 'distance_km': 6.8, 'fare_usd': 10.2}
# Sent: {'ride_id': 9075920, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:09.649016', 'distance_km': 1.57, 'fare_usd': 32.59}
# Sent: {'ride_id': 6951375, 'city': 'New York', 'timestamp': '2025-12-03T16:42:10.652842', 'distance_km': 12.98, 'fare_usd': 5.67}
# Sent: {'ride_id': 5306592, 'city': 'New York', 'timestamp': '2025-12-03T16:42:11.668892', 'distance_km': 9.26, 'fare_usd': 10.4}
# Sent: {'ride_id': 3562566, 'city': 'Chicago', 'timestamp': '2025-12-03T16:42:12.676408', 'distance_km': 6.3, 'fare_usd': 11.4}
# Sent: {'ride_id': 3174411, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:13.678788', 'distance_km': 4.6, 'fare_usd': 22.28}
# Sent: {'ride_id': 7121015, 'city': 'San Francisco', 'timestamp': '2025-12-03T16:42:14.692999', 'distance_km': 11.95, 'fare_usd': 12.55}
# Sent: {'ride_id': 4528754, 'city': 'New York', 'timestamp': '2025-12-03T16:42:15.710867', 'distance_km': 12.59, 'fare_usd': 34.11}
# Sent: {'ride_id': 6518592, 'city': 'San Francisco', 'timestamp': '2025-12-03T16:42:16.711458', 'distance_km': 4.16, 'fare_usd': 14.12}
# Sent: {'ride_id': 9226446, 'city': 'New York', 'timestamp': '2025-12-03T16:42:17.723892', 'distance_km': 4.7, 'fare_usd': 11.54}
# Sent: {'ride_id': 4836012, 'city': 'New York', 'timestamp': '2025-12-03T16:42:18.733734', 'distance_km': 14.43, 'fare_usd': 11.84}
# Sent: {'ride_id': 7692998, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:19.741002', 'distance_km': 11.49, 'fare_usd': 24.57}
# Sent: {'ride_id': 6819168, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:20.752710', 'distance_km': 9.03, 'fare_usd': 38.91}
# Sent: {'ride_id': 4530666, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:21.755608', 'distance_km': 12.75, 'fare_usd': 22.13}
# Sent: {'ride_id': 9752263, 'city': 'San Francisco', 'timestamp': '2025-12-03T16:42:22.770323', 'distance_km': 9.18, 'fare_usd': 36.24}
# Sent: {'ride_id': 3757480, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:23.777004', 'distance_km': 13.95, 'fare_usd': 21.06}
# Sent: {'ride_id': 6091372, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:24.786832', 'distance_km': 9.63, 'fare_usd': 27.41}
# Sent: {'ride_id': 4215883, 'city': 'San Francisco', 'timestamp': '2025-12-03T16:42:25.798544', 'distance_km': 5.97, 'fare_usd': 33.5}
# Sent: {'ride_id': 2701169, 'city': 'Boston', 'timestamp': '2025-12-03T16:42:26.810556', 'distance_km': 12.28, 'fare_usd': 39.63}
# Sent: {'ride_id': 3831543, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:27.825319', 'distance_km': 7.36, 'fare_usd': 15.76}
# Sent: {'ride_id': 7769193, 'city': 'San Francisco', 'timestamp': '2025-12-03T16:42:28.833851', 'distance_km': 13.84, 'fare_usd': 38.98}
# Sent: {'ride_id': 9261167, 'city': 'San Francisco', 'timestamp': '2025-12-03T16:42:29.848421', 'distance_km': 9.28, 'fare_usd': 28.68}
# Sent: {'ride_id': 9563700, 'city': 'Boston', 'timestamp': '2025-12-03T16:42:30.862867', 'distance_km': 13.99, 'fare_usd': 14.12}
# Sent: {'ride_id': 1599666, 'city': 'New York', 'timestamp': '2025-12-03T16:42:31.875194', 'distance_km': 14.2, 'fare_usd': 20.28}
# Sent: {'ride_id': 3312901, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:32.889479', 'distance_km': 9.44, 'fare_usd': 36.74}
# Sent: {'ride_id': 4589182, 'city': 'Chicago', 'timestamp': '2025-12-03T16:42:33.898502', 'distance_km': 6.05, 'fare_usd': 7.6}
# Sent: {'ride_id': 8503960, 'city': 'Boston', 'timestamp': '2025-12-03T16:42:34.912519', 'distance_km': 3.78, 'fare_usd': 15.75}
# Sent: {'ride_id': 7777023, 'city': 'San Francisco', 'timestamp': '2025-12-03T16:42:35.925229', 'distance_km': 4.79, 'fare_usd': 39.03}
# Sent: {'ride_id': 8042352, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:36.936776', 'distance_km': 4.27, 'fare_usd': 27.06}
# Sent: {'ride_id': 9490012, 'city': 'Chicago', 'timestamp': '2025-12-03T16:42:37.950629', 'distance_km': 2.22, 'fare_usd': 10.61}
# Sent: {'ride_id': 8712124, 'city': 'Chicago', 'timestamp': '2025-12-03T16:42:38.966261', 'distance_km': 5.37, 'fare_usd': 33.28}
# Sent: {'ride_id': 6107759, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:39.980310', 'distance_km': 10.66, 'fare_usd': 32.62}
# Sent: {'ride_id': 2904797, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:40.992890', 'distance_km': 11.8, 'fare_usd': 15.33}
# Sent: {'ride_id': 5894032, 'city': 'Chicago', 'timestamp': '2025-12-03T16:42:42.005534', 'distance_km': 6.83, 'fare_usd': 20.05}
# Sent: {'ride_id': 7963531, 'city': 'Boston', 'timestamp': '2025-12-03T16:42:43.017256', 'distance_km': 6.58, 'fare_usd': 15.14}
# Sent: {'ride_id': 9839390, 'city': 'Chicago', 'timestamp': '2025-12-03T16:42:44.017645', 'distance_km': 3.0, 'fare_usd': 28.96}
# Sent: {'ride_id': 1340419, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:45.020820', 'distance_km': 10.23, 'fare_usd': 10.78}
# Sent: {'ride_id': 8785982, 'city': 'Chicago', 'timestamp': '2025-12-03T16:42:46.023128', 'distance_km': 12.41, 'fare_usd': 26.23}
# Sent: {'ride_id': 2804854, 'city': 'Boston', 'timestamp': '2025-12-03T16:42:47.027191', 'distance_km': 12.59, 'fare_usd': 7.24}
# Sent: {'ride_id': 2819395, 'city': 'Boston', 'timestamp': '2025-12-03T16:42:48.032885', 'distance_km': 14.33, 'fare_usd': 7.42}
# Sent: {'ride_id': 7043247, 'city': 'Boston', 'timestamp': '2025-12-03T16:42:49.040746', 'distance_km': 10.49, 'fare_usd': 26.51}
# Sent: {'ride_id': 1478594, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:50.054357', 'distance_km': 9.79, 'fare_usd': 9.35}
# Sent: {'ride_id': 3802414, 'city': 'San Francisco', 'timestamp': '2025-12-03T16:42:51.058111', 'distance_km': 4.8, 'fare_usd': 19.42}
# Sent: {'ride_id': 9507728, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:52.069322', 'distance_km': 6.29, 'fare_usd': 34.21}
# Sent: {'ride_id': 2329178, 'city': 'Chicago', 'timestamp': '2025-12-03T16:42:53.075995', 'distance_km': 9.84, 'fare_usd': 25.53}
# Sent: {'ride_id': 2211877, 'city': 'Chicago', 'timestamp': '2025-12-03T16:42:54.084156', 'distance_km': 5.82, 'fare_usd': 23.95}
# Sent: {'ride_id': 8210745, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:55.085049', 'distance_km': 10.03, 'fare_usd': 30.0}
# Sent: {'ride_id': 9532397, 'city': 'New York', 'timestamp': '2025-12-03T16:42:56.094888', 'distance_km': 8.64, 'fare_usd': 23.7}
# Sent: {'ride_id': 2743292, 'city': 'Boston', 'timestamp': '2025-12-03T16:42:57.103050', 'distance_km': 3.68, 'fare_usd': 23.41}
# Sent: {'ride_id': 3046782, 'city': 'Seattle', 'timestamp': '2025-12-03T16:42:58.120419', 'distance_km': 13.73, 'fare_usd': 11.12}
# Sent: {'ride_id': 6190736, 'city': 'Chicago', 'timestamp': '2025-12-03T16:42:59.123212', 'distance_km': 13.82, 'fare_usd': 29.72}
# Sent: {'ride_id': 7823490, 'city': 'Boston', 'timestamp': '2025-12-03T16:43:00.132405', 'distance_km': 2.27, 'fare_usd': 5.83}
# Sent: {'ride_id': 9295884, 'city': 'San Francisco', 'timestamp': '2025-12-03T16:43:01.137527', 'distance_km': 2.95, 'fare_usd': 28.3}
# Sent: {'ride_id': 4417279, 'city': 'Boston', 'timestamp': '2025-12-03T16:43:02.139374', 'distance_km': 5.65, 'fare_usd': 28.03}
# Sent: {'ride_id': 6024942, 'city': 'New York', 'timestamp': '2025-12-03T16:43:03.143841', 'distance_km': 9.09, 'fare_usd': 22.3}
# Sent: {'ride_id': 7710165, 'city': 'Chicago', 'timestamp': '2025-12-03T16:43:04.154691', 'distance_km': 14.15, 'fare_usd': 34.11}
# Sent: {'ride_id': 1404610, 'city': 'Chicago', 'timestamp': '2025-12-03T16:43:05.167030', 'distance_km': 14.36, 'fare_usd': 19.42}
