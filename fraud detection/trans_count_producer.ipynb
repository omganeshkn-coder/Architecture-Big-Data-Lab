# %%
import json
import time
import random
from datetime import datetime
from kafka import KafkaProducer

producer = KafkaProducer(
    bootstrap_servers='localhost:9092',
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

accounts = [('ICIC0000072', 123456), ('ICIC0000072', 123457), ('SBIN0004426', 200001), ('SBIN0004426', 200002), ('CNRB0010233', 400001), ('CNRB0010233', 400002) ]
transaction = ['C', 'D', 'F']


def generate_transaction_event():
    account_detail = random.choice(accounts)
    return {
        "txn_id": account_detail[1],
        "IFSC_Code": account_detail[0],
        "txn_type": random.choice(transaction),
        "timestamp": datetime.now().isoformat(),
        "amount": random.randint(1, 200000)
    }

print("Producing Transaction events...")

while True:
    event = generate_transaction_event()
    producer.send("transactions-count1", event)
    print("Sent:", event)
    time.sleep(1)
# Out:
# Producing Transaction events...
# Sent: {'txn_id': 200001, 'IFSC_Code': 'SBIN0004426', 'txn_type': 'D', 'timestamp': '2025-12-03T09:40:55.584224', 'amount': 14902}
# Sent: {'txn_id': 400002, 'IFSC_Code': 'CNRB0010233', 'txn_type': 'F', 'timestamp': '2025-12-03T09:40:56.699986', 'amount': 38882}
# Sent: {'txn_id': 200001, 'IFSC_Code': 'SBIN0004426', 'txn_type': 'F', 'timestamp': '2025-12-03T09:40:57.711011', 'amount': 130679}
# Sent: {'txn_id': 200002, 'IFSC_Code': 'SBIN0004426', 'txn_type': 'D', 'timestamp': '2025-12-03T09:40:58.726652', 'amount': 6874}
# Sent: {'txn_id': 200001, 'IFSC_Code': 'SBIN0004426', 'txn_type': 'F', 'timestamp': '2025-12-03T09:40:59.739395', 'amount': 90711}
# Sent: {'txn_id': 123456, 'IFSC_Code': 'ICIC0000072', 'txn_type': 'C', 'timestamp': '2025-12-03T09:41:00.748960', 'amount': 78679}
# Sent: {'txn_id': 200002, 'IFSC_Code': 'SBIN0004426', 'txn_type': 'C', 'timestamp': '2025-12-03T09:41:01.758138', 'amount': 106455}
# Sent: {'txn_id': 123457, 'IFSC_Code': 'ICIC0000072', 'txn_type': 'C', 'timestamp': '2025-12-03T09:41:02.769711', 'amount': 117100}
# Sent: {'txn_id': 123456, 'IFSC_Code': 'ICIC0000072', 'txn_type': 'F', 'timestamp': '2025-12-03T09:41:03.776742', 'amount': 102758}
# Sent: {'txn_id': 123456, 'IFSC_Code': 'ICIC0000072', 'txn_type': 'F', 'timestamp': '2025-12-03T09:41:04.783606', 'amount': 123693}
# Sent: {'txn_id': 400001, 'IFSC_Code': 'CNRB0010233', 'txn_type': 'F', 'timestamp': '2025-12-03T09:41:05.785420', 'amount': 136226}
# Sent: {'txn_id': 200001, 'IFSC_Code': 'SBIN0004426', 'txn_type': 'F', 'timestamp': '2025-12-03T09:41:06.791527', 'amount': 104542}
# Sent: {'txn_id': 400002, 'IFSC_Code': 'CNRB0010233', 'txn_type': 'F', 'timestamp': '2025-12-03T09:41:07.795880', 'amount': 147145}
# Sent: {'txn_id': 123457, 'IFSC_Code': 'ICIC0000072', 'txn_type': 'D', 'timestamp': '2025-12-03T09:41:08.808750', 'amount': 133196}
# Sent: {'txn_id': 200002, 'IFSC_Code': 'SBIN0004426', 'txn_type': 'C', 'timestamp': '2025-12-03T09:41:09.810201', 'amount': 81380}
# Sent: {'txn_id': 123456, 'IFSC_Code': 'ICIC0000072', 'txn_type': 'C', 'timestamp': '2025-12-03T09:41:10.813830', 'amount': 65648}
# Sent: {'txn_id': 123456, 'IFSC_Code': 'ICIC0000072', 'txn_type': 'F', 'timestamp': '2025-12-03T09:41:11.821124', 'amount': 4453}
# Sent: {'txn_id': 123457, 'IFSC_Code': 'ICIC0000072', 'txn_type': 'C', 'timestamp': '2025-12-03T09:41:12.833429', 'amount': 43940}
# Sent: {'txn_id': 123457, 'IFSC_Code': 'ICIC0000072', 'txn_type': 'C', 'timestamp': '2025-12-03T09:41:13.843923', 'amount': 148251}
# Sent: {'txn_id': 123456, 'IFSC_Code': 'ICIC0000072', 'txn_type': 'D', 'timestamp': '2025-12-03T09:41:14.855272', 'amount': 192073}
# Sent: {'txn_id': 200002, 'IFSC_Code': 'SBIN0004426', 'txn_type': 'C', 'timestamp': '2025-12-03T09:41:15.871184', 'amount': 109944}
# Sent: {'txn_id': 123457, 'IFSC_Code': 'ICIC0000072', 'txn_type': 'F', 'timestamp': '2025-12-03T09:41:16.886367', 'amount': 50071}
# Sent: {'txn_id': 200001, 'IFSC_Code': 'SBIN0004426', 'txn_type': 'F', 'timestamp': '2025-12-03T09:41:17.892526', 'amount': 27686}
# Sent: {'txn_id': 123456, 'IFSC_Code': 'ICIC0000072', 'txn_type': 'C', 'timestamp': '2025-12-03T09:41:18.896662', 'amount': 182592}
# Sent: {'txn_id': 400002, 'IFSC_Code': 'CNRB0010233', 'txn_type': 'C', 'timestamp': '2025-12-03T09:41:19.900419', 'amount': 154340}
# Sent: {'txn_id': 400002, 'IFSC_Code': 'CNRB0010233', 'txn_type': 'C', 'timestamp': '2025-12-03T09:41:20.906314', 'amount': 34702}
# Sent: {'txn_id': 400002, 'IFSC_Code': 'CNRB0010233', 'txn_type': 'D', 'timestamp': '2025-12-03T09:41:21.910315', 'amount': 186075}
# Sent: {'txn_id': 200001, 'IFSC_Code': 'SBIN0004426', 'txn_type': 'D', 'timestamp': '2025-12-03T09:41:22.913122', 'amount': 125222}
# Sent: {'txn_id': 123456, 'IFSC_Code': 'ICIC0000072', 'txn_type': 'F', 'timestamp': '2025-12-03T09:41:23.917121', 'amount': 106362}
# Sent: {'txn_id': 200002, 'IFSC_Code': 'SBIN0004426', 'txn_type': 'C', 'timestamp': '2025-12-03T09:41:24.928126', 'amount': 157197}
# Sent: {'txn_id': 400001, 'IFSC_Code': 'CNRB0010233', 'txn_type': 'F', 'timestamp': '2025-12-03T09:41:25.940893', 'amount': 156713}
# Sent: {'txn_id': 400001, 'IFSC_Code': 'CNRB0010233', 'txn_type': 'F', 'timestamp': '2025-12-03T09:41:26.952022', 'amount': 113635}
# Sent: {'txn_id': 400001, 'IFSC_Code': 'CNRB0010233', 'txn_type': 'C', 'timestamp': '2025-12-03T09:41:27.961341', 'amount': 99489}
# Sent: {'txn_id': 400001, 'IFSC_Code': 'CNRB0010233', 'txn_type': 'C', 'timestamp': '2025-12-03T09:41:28.972954', 'amount': 20399}
# Sent: {'txn_id': 400001, 'IFSC_Code': 'CNRB0010233', 'txn_type': 'F', 'timestamp': '2025-12-03T09:41:29.977047', 'amount': 16449}
# Sent: {'txn_id': 123457, 'IFSC_Code': 'ICIC0000072', 'txn_type': 'D', 'timestamp': '2025-12-03T09:41:30.990041', 'amount': 158830}
# Sent: {'txn_id': 200002, 'IFSC_Code': 'SBIN0004426', 'txn_type': 'D', 'timestamp': '2025-12-03T09:41:31.998861', 'amount': 167729}
# Sent: {'txn_id': 400001, 'IFSC_Code': 'CNRB0010233', 'txn_type': 'F', 'timestamp': '2025-12-03T09:41:33.010944', 'amount': 31500}
# Sent: {'txn_id': 123456, 'IFSC_Code': 'ICIC0000072', 'txn_type': 'C', 'timestamp': '2025-12-03T09:41:34.020906', 'amount': 98958}
# Sent: {'txn_id': 123457, 'IFSC_Code': 'ICIC0000072', 'txn_type': 'D', 'timestamp': '2025-12-03T09:41:35.035846', 'amount': 14242}
# Sent: {'txn_id': 200001, 'IFSC_Code': 'SBIN0004426', 'txn_type': 'D', 'timestamp': '2025-12-03T09:41:36.039165', 'amount': 32422}
# Sent: {'txn_id': 400001, 'IFSC_Code': 'CNRB0010233', 'txn_type': 'F', 'timestamp': '2025-12-03T09:41:37.053487', 'amount': 184223}
# Sent: {'txn_id': 200001, 'IFSC_Code': 'SBIN0004426', 'txn_type': 'C', 'timestamp': '2025-12-03T09:41:38.069572', 'amount': 27615}
# Sent: {'txn_id': 400002, 'IFSC_Code': 'CNRB0010233', 'txn_type': 'F', 'timestamp': '2025-12-03T09:41:39.084655', 'amount': 129861}
